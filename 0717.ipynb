# %%
from pandas_datareader import data as pdr
import yfinance as yf
yf.pdr_override()

# %%
psny=pdr.get_data_yahoo('PSNY', start='2022-07-01')
psny_dpc=(psny['Close']/psny['Close'].shift(1)-1)*100
psny_dpc.iloc[0]=0
psny_dpc_cp=((psny_dpc+100)/100).cumprod()*100-100

msft=pdr.get_data_yahoo('MSFT', start='2022-07-01')
msft_dpc=(msft['Close']/msft['Close'].shift(1)-1)*100
msft_dpc.iloc[0]=0
msft_dpc_cp=((msft_dpc+100)/100).cumprod()*100-100
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
import matplotlib.pyplot as plt

plt.plot(psny.index, psny_dpc_cp, 'b', label='PSNY')
plt.plot(msft.index, msft_dpc_cp, 'r--', label='MSFT')
plt.legend(loc='best')
plt.grid(True)
plt.show()

# %%
from pandas_datareader import data as pdr
import yfinance as yf
yf.pdr_override()
import matplotlib.pyplot as plt

# %%
kospi=pdr.get_data_yahoo('^KS11', start='2004-01-04')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
window=252
peak=kospi['Adj Close'].rolling(window, min_periods=1).max()
drawdown=kospi['Adj Close']/peak-1.0
max_dd=drawdown.rolling(window, min_periods=1).min()

plt.figure(figsize=(9,7))
plt.subplot(211)
kospi['Close'].plot(label='KOSPI', title='KOSPI MDD', grid=True, legend=True)
plt.subplot(212)
drawdown.plot(c='blue', label='KOSPI MDD', grid=True, legend=True)
max_dd.plot(c='red', label='KOSPI MAX MDD', grid=True, legend=True)
plt.show()

# %%
max_dd.min()
# Out:
# -0.5453665130144085

# %%
max_dd[max_dd==-0.5453665130144085]
# Out:
# Date
# 2008-10-24   -0.545367
# 2008-10-27   -0.545367
# 2008-10-28   -0.545367
# 2008-10-29   -0.545367
# 2008-10-30   -0.545367
#                 ...
# 2009-10-16   -0.545367
# 2009-10-19   -0.545367
# 2009-10-20   -0.545367
# 2009-10-21   -0.545367
# 2009-10-22   -0.545367
# Name: Adj Close, Length: 252, dtype: float64

# %%
from pandas_datareader import data as pdr
import yfinance as yf
yf.pdr_override()

# %%
psny=pdr.get_data_yahoo('PSNY', start='2022-07-01')

window=12
peak=psny['Close'].rolling(window, min_periods=1).max()
drawdown=psny['Close']/peak-1
max_dd=drawdown.rolling(window, min_periods=1).min()

plt.figure(figsize=(9,7))
plt.subplot(211)
psny['Close'].plot(label='PSNY', title='PSNY MDD', grid=True, legend=True)
plt.subplot(212)
drawdown.plot(c='blue', label='PSNY MDD', grid=True, legend=True)
max_dd.plot(c='red', label='PSNY MAX MDD', grid=True, legend=True)
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
from pandas_datareader import data as pdr
import yfinance as yf
yf.pdr_override()
import matplotlib.pyplot as plt

# %%
samsung=pdr.get_data_yahoo('005930.KS', start='2004-01-01')

window=252
peak=samsung['Close'].rolling(window, min_periods=1).max()
drawdown=samsung['Close']/peak-1
max_dd=drawdown.rolling(window, min_periods=1).min()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
plt.figure(figsize=(9,7))
plt.subplot(211)
samsung['Close'].plot(label='SAMSUNG', title='SAMSUNG MDD', grid=True, legend=True)
plt.subplot(212)
drawdown.plot(c='blue', label='SAMSUGN DD', grid=True, legend=True)
max_dd.plot(c='red', label='KOSPI MDD', grid=True, legend=True)
plt.show()

# %%
from pandas_datareader import data as pdr
import yfinance as yf
yf.pdr_override()
import matplotlib.pyplot as plt

# %%
msft=pdr.get_data_yahoo('SPY', start='2004-01-01')

window=252
peak=msft['Close'].rolling(window, min_periods=1).max()
drawdown=msft['Close']/peak-1
max_dd=drawdown.rolling(window, min_periods=1).min()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
plt.figure(figsize=(9,7))
plt.subplot(211)
msft['Close'].plot(label='MSFT', title='MSFT MDD', grid=True, legend=True)
plt.subplot(212)
drawdown.plot(c='blue', label='MSFT DD', grid=True, legend=True)
max_dd.plot(c='red', label='MSFT MDD', grid=True, legend=True)
plt.show()

# %%
from pandas_datareader import data as pdr
import yfinance as yf
yf.pdr_override()

# %%
psny=pdr.get_data_yahoo('^KS11', start='2004-01-01')
psny_dpc=(psny['Close']/psny['Close'].shift(1)-1)*100
psny_dpc.iloc[0]=0
psny_dpc_cp=((psny_dpc+100)/100).cumprod()*100-100

msft=pdr.get_data_yahoo('MSFT', start='2004-01-01')
msft_dpc=(msft['Close']/msft['Close'].shift(1)-1)*100
msft_dpc.iloc[0]=0
msft_dpc_cp=((msft_dpc+100)/100).cumprod()*100-100
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
import matplotlib.pyplot as plt

plt.plot(psny.index, psny_dpc_cp, 'b', label='psny')
plt.plot(msft.index, msft_dpc_cp, 'r--', label='msft')
plt.show()

# %%
from pandas_datareader import data as pdr
import yfinance as yf
yf.pdr_override()
import matplotlib.pyplot as plt

# %%
msft=pdr.get_data_yahoo('MSFT', start='2001-01-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
window=252
peak=msft['Close'].rolling(window, min_periods=1).max()
drawdown=msft['Close']/peak-1
max_dd=drawdown.rolling(window, min_periods=1).min()

# %%
plt.figure(figsize=(9,7))
plt.subplot(211)
msft['Close'].plot(label='MSFT', title='MSFT DD', grid=True, legend=True)
plt.subplot(212)
drawdown.plot(c='blue', label='MSFT DD', grid=True, legend=True )
max_dd.plot(c='red', label='MSFT MDD', grid=True, legend=True)
plt.show()

# %%
from pandas_datareader import data as pdr
import yfinance as yf
yf.pdr_override()
import matplotlib.pyplot as plt

kospi=pdr.get_data_yahoo('^KS11', start='2005-01-01')
msft=pdr.get_data_yahoo('MSFT', start='2005-01-01')

kospi_dpc=(kospi['Close']/kospi['Close'].shift(1)-1)*100
kospi_dpc.iloc[0]=0
kospi_dpc_cp=((100+kospi_dpc)/100).cumprod()*100-100

msft_dpc=(msft['Close']/msft['Close'].shift(1)-1)*100
msft_dpc.iloc[0]=0
msft_dpc_cp
